# %% [markdown]
# ## Business Problem

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load_DataSet

# %%
path = pd.read_csv("/content/drive/MyDrive/Final Project ML/student marks predictor/student_info.csv")
path
# Out:
#      Study_Hours  Student_Marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 194         7.53          81.67
# 195         8.56          84.68
# 196         8.94          86.75
# 197         6.60          78.05
# 198         8.35          83.50
#
# [199 rows x 2 columns]

# %%
path.head()
# Out:
#    Study_Hours  Student_Marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
path.tail()
# Out:
#      Study_Hours  Student_Marks
# 194         7.53          81.67
# 195         8.56          84.68
# 196         8.94          86.75
# 197         6.60          78.05
# 198         8.35          83.50

# %%
path.describe()
# Out:
#        Study_Hours  Student_Marks
# count   198.000000     199.000000
# mean      6.975051      77.942764
# std       1.258245       4.936469
# min       4.990000      68.570000
# 25%       5.752500      73.370000
# 50%       7.055000      77.770000
# 75%       8.077500      82.340000
# max       8.990000      86.990000

# %%
path.shape
# Out:
# (199, 2)

# %% [markdown]
# ## Visualize and insight from the data

# %%
path.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Study_Hours    198 non-null    float64
#  1   Student_Marks  199 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
path.describe()
# Out:
#        Study_Hours  Student_Marks
# count   198.000000     199.000000
# mean      6.975051      77.942764
# std       1.258245       4.936469
# min       4.990000      68.570000
# 25%       5.752500      73.370000
# 50%       7.055000      77.770000
# 75%       8.077500      82.340000
# max       8.990000      86.990000

# %%
plt.scatter( x = path.Study_Hours , y =path.Student_Marks)
plt.xlabel("Student Hours")
plt.ylabel("Student Marks")
plt.title("Scatter plot for Student Score Predictor")
plt.show()

# %% [markdown]
# ## prepare data for machine learning

# %%
# data cleaning

# %%
path.isnull()
# Out:
#      Study_Hours  Student_Marks
# 0          False          False
# 1          False          False
# 2           True          False
# 3          False          False
# 4          False          False
# ..           ...            ...
# 194        False          False
# 195        False          False
# 196        False          False
# 197        False          False
# 198        False          False
#
# [199 rows x 2 columns]

# %%
path.isnull().sum
# Out:
# <bound method DataFrame.sum of      Study_Hours  Student_Marks
# 0          False          False
# 1          False          False
# 2           True          False
# 3          False          False
# 4          False          False
# ..           ...            ...
# 194        False          False
# 195        False          False
# 196        False          False
# 197        False          False
# 198        False          False
#
# [199 rows x 2 columns]>

# %%
path.isnull().sum()
# Out:
# Study_Hours      1
# Student_Marks    0
# dtype: int64

# %%
path.mean()
# Out:
# Study_Hours       6.975051
# Student_Marks    77.942764
# dtype: float64

# %%
path2 = path.fillna(path.mean())

# %%
path2
# Out:
#      Study_Hours  Student_Marks
# 0       6.830000          78.50
# 1       6.560000          76.74
# 2       6.975051          78.68
# 3       5.670000          71.82
# 4       8.670000          84.19
# ..           ...            ...
# 194     7.530000          81.67
# 195     8.560000          84.68
# 196     8.940000          86.75
# 197     6.600000          78.05
# 198     8.350000          83.50
#
# [199 rows x 2 columns]

# %%
path2.isnull().sum()
# Out:
# Study_Hours      0
# Student_Marks    0
# dtype: int64

# %%
path2.head()
# Out:
#    Study_Hours  Student_Marks
# 0     6.830000          78.50
# 1     6.560000          76.74
# 2     6.975051          78.68
# 3     5.670000          71.82
# 4     8.670000          84.19

# %%
#split data der

# %%
X = path2.drop("Student_Marks" , axis= "columns")
y = path2.drop("Study_Hours" , axis= "columns")

# %%
print ("Shape of X =" , X.shape)
print("shape of y = ", y.shape)
# Out:
# Shape of X = (199, 1)
# shape of y =  (199, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, random_state = 50)
print ("Shape of X =" , X_train.shape)
print("shape of y = ", y_train.shape)
print("Shape of X =" , X_test.shape)
print("shape of y = ",y_test.shape)
# Out:
# Shape of X = (159, 1)
# shape of y =  (159, 1)
# Shape of X = (40, 1)
# shape of y =  (40, 1)

# %% [markdown]
# ## select model and train it

# %%
#y = m*x + c
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train , y_train )
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[3.74523425]])

# %%
lr.intercept_
# Out:
# array([51.7489894])

# %%
# how math work in Machine learningm
m = 3.74
c = 51.74
y = m * 4+c
y
# Out:
# 66.7

# %%
#machine learning model direct learn this
lr.predict([[4]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[66.72992641]])

# %%
lr.predict([[4]])[0][0].round(2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(66.73)

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[83.02169542],
#        [72.16051608],
#        [79.08919946],
#        [79.53862757],
#        [84.29507507],
#        [85.23138363],
#        [81.52360172],
#        [71.18675518],
#        [78.93939009],
#        [71.52382626],
#        [80.77455487],
#        [81.52360172],
#        [80.58729316],
#        [73.65860979],
#        [81.97302983],
#        [81.56105406],
#        [76.69224953],
#        [71.86089734],
#        [84.51978913],
#        [84.6695985 ],
#        [85.00666958],
#        [75.53122691],
#        [71.93580203],
#        [74.25784727],
#        [85.19393129],
#        [70.99949347],
#        [76.69224953],
#        [78.3401526 ],
#        [80.28767442],
#        [71.29911221],
#        [82.1228392 ],
#        [84.36997976],
#        [81.48614938],
#        [79.57607991],
#        [74.37020429],
#        [72.49758717],
#        [82.01048217],
#        [77.02932062],
#        [84.81940787],
#        [71.89834969]])

# %%
pd.DataFrame(np.c_[X_test, y_test, y_pred ] , columns = ["study_hours" , " student mark original ", "student mark predcted"])
# Out:
#     study_hours   student mark original   student mark predcted
# 0          8.35                    83.50              83.021695
# 1          5.45                    70.96              72.160516
# 2          7.30                    79.49              79.089199
# 3          7.42                    82.18              79.538628
# 4          8.69                    85.48              84.295075
# 5          8.94                    86.75              85.231384
# 6          7.95                    82.68              81.523602
# 7          5.19                    70.66              71.186755
# 8          7.26                    79.87              78.939390
# 9          5.28                    70.27              71.523826
# 10         7.75                    79.50              80.774555
# 11         7.95                    82.03              81.523602
# 12         7.70                    80.81              80.587293
# 13         5.85                    75.02              73.658610
# 14         8.07                    82.30              81.973030
# 15         7.96                    83.33              81.561054
# 16         6.66                    76.63              76.692250
# 17         5.37                    71.80              71.860897
# 18         8.75                    85.95              84.519789
# 19         8.79                    84.60              84.669598
# 20         8.88                    85.78              85.006670
# 21         6.35                    76.19              75.531227
# 22         5.39                    73.02              71.935802
# 23         6.01                    75.36              74.257847
# 24         8.93                    85.96              85.193931
# 25         5.14                    71.22              70.999493
# 26         6.66                    76.83              76.692250
# 27         7.10                    76.76              78.340153
# 28         7.62                    79.53              80.287674
# 29         5.22                    70.51              71.299112
# 30         8.11                    83.82              82.122839
# 31         8.71                    85.98              84.369980
# 32         7.94                    82.93              81.486149
# 33         7.43                    80.31              79.576080
# 34         6.04                    72.33              74.370204
# 35         5.54                    72.01              72.497587
# 36         8.08                    81.70              82.010482
# 37         6.75                    77.07              77.029321
# 38         8.83                    85.04              84.819408
# 39         5.38                    71.94              71.898350

# %% [markdown]
# ## Fine tune your model

# %%
lr.score(X_test , y_test)   # here to cheak the accuracy
# Out:
# 0.9591026044885573

# %%
plt.scatter(X_train , y_train)

# %%
plt.scatter(X_test , y_test)
plt.plot(X_train , lr.predict(X_train) , color="r")

# %% [markdown]
# ## present your soloution

# %% [markdown]
# ## save model

# %%
import joblib
joblib.dump(lr , "sudent_mark_pred_model.pkl")
# Out:
# ['sudent_mark_pred_model.pkl']

# %%
model = joblib.load("sudent_mark_pred_model.pkl")
model.predict([[5]])[0][0]
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(70.47516066957452)
